# %% [markdown]
# ## **Setting up the Necessities**

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Sports Activity Recognizer
# Out:
# /content/drive/My Drive/Sports Activity Recognizer

# %%
version = 3
img_path = 'test-images'
model_path = f'models/sports-action-recognizer-version{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# ## **Inference 1**

# %% [markdown]
# Target: Cricket Batting

# %%
img = Image.open(f'{img_path}/img1.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/img1.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('cricket batting',
#  tensor(4),
#  tensor([7.1219e-04, 3.6198e-04, 1.0604e-04, 3.6487e-04, 9.9657e-01, 6.1440e-05,
#          2.6034e-04, 1.4288e-04, 4.8458e-05, 6.3068e-06, 7.2549e-05, 7.9244e-04,
#          4.2316e-04, 4.2805e-05, 3.8006e-05]))

# %% [markdown]
# ## **Inference 2**

# %% [markdown]
# Target: Skiing Parallel

# %%
img = Image.open(f'{img_path}/img2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=111x128>

# %%
model.predict(f'{img_path}/img2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('skiing parallel',
#  tensor(11),
#  tensor([4.1721e-09, 4.6075e-09, 2.3434e-09, 2.2414e-10, 1.5210e-08, 3.6711e-09,
#          8.5434e-09, 2.0951e-09, 2.6259e-07, 1.9925e-06, 9.9153e-10, 1.0000e+00,
#          1.6991e-09, 1.4522e-09, 2.0457e-10]))

# %% [markdown]
# ## **Inference 3**

# %% [markdown]
# Target: Basketball Shoot

# %%
img = Image.open(f'{img_path}/img3.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/img3.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('soccer kick',
#  tensor(12),
#  tensor([1.0882e-06, 6.2757e-05, 3.8287e-02, 5.6820e-04, 3.5039e-05, 5.8696e-03,
#          3.7166e-06, 2.0949e-03, 8.6303e-06, 1.0072e-03, 6.4687e-02, 7.4030e-05,
#          6.7963e-01, 3.9592e-05, 2.0763e-01]))

# %% [markdown]
# ## **Inference 4**

# %% [markdown]
# Target: Rowing

# %%
img = Image.open(f'{img_path}/img4.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/img4.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('rowing',
#  tensor(9),
#  tensor([1.5280e-08, 2.0044e-07, 2.2127e-08, 1.2108e-08, 6.4367e-11, 5.9187e-08,
#          1.1926e-09, 2.4253e-09, 6.1604e-10, 1.0000e+00, 4.7867e-09, 8.2942e-09,
#          2.4343e-09, 9.1465e-10, 1.6652e-09]))

# %% [markdown]
# ## **Inference 5**

# %% [markdown]
# Target: Horse Riding Gallop

# %%
img = Image.open(f'{img_path}/img5.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x126>

# %%
model.predict(f'{img_path}/img5.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('horse riding gallop',
#  tensor(7),
#  tensor([3.9386e-06, 2.5810e-08, 9.9372e-06, 4.2853e-07, 2.4130e-08, 2.7685e-07,
#          7.2403e-07, 9.9998e-01, 2.7591e-06, 6.6184e-08, 1.1084e-07, 3.3680e-07,
#          2.2370e-06, 1.0281e-07, 2.2860e-06]))
